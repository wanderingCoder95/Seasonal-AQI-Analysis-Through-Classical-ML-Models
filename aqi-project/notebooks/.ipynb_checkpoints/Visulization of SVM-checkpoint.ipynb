# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('../data/india_city_aqi_2015_2023-cleaned_dataset.csv')
df.head()
# Out:
#     city        date       pm2.5        pm10        no2        so2        co  \
# 0  Delhi  2015-01-01   99.868566  147.103280  49.715328  19.615149  0.729754
# 1  Delhi  2015-01-02  143.168513  208.517207  32.957884  14.712800  0.660975
# 2  Delhi  2015-01-03   89.678491  101.412886  14.126233   9.188562  0.496151
# 3  Delhi  2015-01-04   43.679037   65.432963  61.984732  10.871118  0.820258
# 4  Delhi  2015-01-05   58.224691  110.443143  22.735096  13.878490  0.619808
#
#           o3  aqi  aqi_category  pm2.5/pm10 ratio  season
# 0  46.487946  103      Moderate          0.678901  Winter
# 1  43.014054  141      Moderate          0.686603  Winter
# 2  54.713710   82  Satisfactory          0.884291  Winter
# 3  28.628777   50          Good          0.667539  Winter
# 4  45.624594   69  Satisfactory          0.527192  Winter

# %%
# Drop unnecessary columns
df = df.drop(columns=["date", "aqi"], errors='ignore')

# Extract season if datetime exists
if "datetime" in df.columns:
    df["datetime"] = pd.to_datetime(df["datetime"])
    df["season"] = df["datetime"].dt.month % 12 // 3 + 1

# One-hot encoding
df = pd.get_dummies(df, columns=["city", "season"], drop_first=True)

# %%
label_encoder = LabelEncoder()

df["AQI_Category_Encoded"] = label_encoder.fit_transform(df["aqi_category"])

y = df["AQI_Category_Encoded"]
X = df.drop(columns=["aqi_category", "AQI_Category_Encoded"])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Explained variance ratio: [0.12572273 0.07025164]

# %%
svm_pca = SVC(kernel='rbf', C=1, gamma='scale')
svm_pca.fit(X_pca, y)
# Out:
# SVC(C=1)

# %%
def plot_decision_boundary(X, y, model):
    h = 0.02

    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

    xx, yy = np.meshgrid(
        np.arange(x_min, x_max, h),
        np.arange(y_min, y_max, h)
    )

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(10, 6))
    plt.contourf(xx, yy, Z, alpha=0.3)

    scatter = plt.scatter(
        X[:, 0], X[:, 1],
        c=y,
        cmap='viridis',
        edgecolor='k'
    )

    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.title("SVM Decision Boundary (PCA Reduced Data)")
    plt.colorbar(scatter)
    plt.show()

# %%
plot_decision_boundary(X_pca, y, svm_pca)
